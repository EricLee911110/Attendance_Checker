# %%
import pandas as pd
import sys
$ pip install -U jupyter
$ pipenv update jupyter
# !{sys.executable} -m pip install openpyxl
print("Done!")
total_df = pd.read_excel('A班點名單.xlsx', header=None)
real_df = pd.read_excel('test.xlsx', header=None)

combined = "";
for cell in real_df.iloc[:,0]:
    combined += str(cell)

names = total_df.iloc[:,0]
missed_names = []
for name in names:
    if name not in combined:
        missed_names.append(name)
print(missed_names)
print(len(missed_names))
